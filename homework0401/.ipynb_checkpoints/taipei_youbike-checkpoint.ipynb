# %% [markdown]
# # 臺北市Youbike即時資料
# ### 資料來源 ： http://data.taipei/youbike
# ### 資料介紹： [YouBike臺北市公共自行車即時資訊](https://data.taipei/dataset/detail/metadata?id=8ef1626a-892a-4218-8344-f7ac46e1aa48)

# %%
import pandas as pd

# %%
# import gzip
import pandas as pd

### 檔案格式為經gz壓縮之json檔，可透過pandas.read_json()中的compression進行解壓縮
df = pd.read_json('http://data.taipei/youbike', compression='gzip', encoding='utf-8')
df.head()
# Out:
#    retCode                                             retVal
# 1        1  {'sno': '0001', 'sna': '捷運市政府站(3號出口)', 'tot': ...
# 2        1  {'sno': '0002', 'sna': '捷運國父紀念館站(2號出口)', 'tot'...
# 3        1  {'sno': '0003', 'sna': '台北市政府', 'tot': '40', '...
# 4        1  {'sno': '0004', 'sna': '市民廣場', 'tot': '60', 's...
# 5        1  {'sno': '0005', 'sna': '興雅國中', 'tot': '60', 's...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-78a33f69c558> in <module>()
# ----> 1 df[1]
#
# ...
